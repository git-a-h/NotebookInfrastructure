# %%
import ipytest
import pytest
ipytest.autoconfig()

# %%
import os
import sys

cwd = os.getcwd()
parent = os.path.abspath(os.path.join(cwd,os.pardir))
root = os.path.abspath(os.path.join(parent,os.pardir))


sys.path.append(root)

# %%
from src.step_3.dummy_mult import mult
mult(3,3)
# Out:
# 9

# %%
T = int | float | complex
def mult2(a:T,b:T) -> T:
    return a*b

# %%
# %%ipytest -v
# cwd = os.getcwd()
# parent = os.path.abspath(os.path.join(cwd,os.pardir))
# root = os.path.abspath(os.path.join(parent,os.pardir))
#
# sys.path.append(root)
#
# from src.step_3.dummy_mult import mult
# print(mult)
# def test_mult():
#     assert mult(1,1) == 1
# Out:
# <function mult at 0x1084b5dd0>
# ======================================= test session starts ========================================
# platform darwin -- Python 3.14.0, pytest-9.0.1, pluggy-1.6.0
# rootdir: /Users/andyhuynh/Documents/Stud/BSc/TUHH/09/rse_seminar/NotebookInfrastructure/tests/step_3
# plugins: anyio-4.11.0, cov-7.0.0
# collected 0 items
#
# ====================================== no tests ran in 0.00s =======================================

# %%
import ipytest, sys
print(sys.executable)
import pytest
print(pytest.__file__)
print(pytest.__version__)
# Out:
# /Users/andyhuynh/micromamba/envs/rse_seminar/bin/python
# /Users/andyhuynh/micromamba/envs/rse_seminar/lib/python3.14/site-packages/pytest/__init__.py
# 9.0.1

# %%
# %%ipytest -qq
# def test_simple():
#     assert 1+1 ==2
